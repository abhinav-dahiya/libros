# %% [markdown]
# # Comparing Writing Styles
#
# ## Using Word Embeddings and Dynamic Time Warping

# %%
# %matplotlib inline

from gensim.models import Word2Vec
import numpy as np
import cPickle
import nltk.data
import pyprind
import matplotlib.pyplot as plt
import seaborn
seaborn.set_style("whitegrid")

from sklearn.decomposition import RandomizedPCA
from utils import book_data
from fastdtw import fastdtw
from sklearn import manifold
from scipy.signal import gaussian
from sklearn.cluster import KMeans

import os
import sys
reload(sys)
sys.setdefaultencoding("utf8")

# %% [markdown]
# ### Load word2vec model
# Train using `train_word2vec.py` in `src\utils`

# %%
model = Word2Vec.load("data/word2vec_model")

# %% [markdown]
# ### Find cluster centers

# %%
vecs = []
word_names = []
for word in model.vocab:
    vecs.append(model[word])
    word_names.append(word)
    
vecs = np.array(vecs)
km = Kmeans(n_clusters=4)
km.fit(vecs)

# %% [markdown]
# ### Start Reading books

# %%
# Find all books for comparison
root_path = "../gutenberg"

all_books = []
for f in os.listdir(root_path):
    if f.endswith(".epub"):
        all_books.append(f)

# %% [markdown]
# ### Get Sentence vectors

# %%
items = []
tokenizer = nltk.data.load("tokenizers\punkt\english.pickle")

bar = pyprind.ProgBar(len(all_books))
for book in all_books:
    try:
        item = {"name": book, "data": book_data.get_sentence_vector(os.path.join(root_path, book), model, tokenizer)}
        items.append(item)
    except:
        continue
    finally:
        bar.update()

# %%
indices = []

for idx, item in enumerate(items):
    if item["name"] in all_books:
        indices.append(idx)

# %% [markdown]
# ### Dtw distance

# %%
def dtw_distance(sig_one, sig_two, fft=False):
    """
    Return dtw distance
    """
    
    if fft:
        sig_one = np.fft.fftn(sig_one)
        sig_two = np.fft.fftn(sig_two)
        
    d = fastdtw(sig_one, sig_two, dist=lambda a, b: sum((a - b) ** 2) ** 0.5)[0]
    return np.sqrt(np.abs(d ** 2))

# %% [markdown]
# ### Filters

# %%
def gauss(x, y):
	b = gaussian(200, 60)
	ga = filters.convolve1d(y, b/b.sum())
	return ga

def cos_sim(a, b):
    return np.dot(a, b.T) / (np.linalg.norm(a) * np.linalg.norm(b))

def clean(idx):
    y = items[idx]["data"]
    x = xrange(y.shape[0])
    y = cos_sim(y, km.cluster_centers_)
    
    # Filter
    new = np.zeros(y.shape)
    for i in xrange(y.shape[1]):
        new[:, i] = testGauss(x, y[:, i])
    
    return new

# %% [markdown]
# ### Generating distance matrix

# %%
lim = len(all_books)
distances = -1 * np.ones((lim, lim))

bar = pyprind.ProgBar(lim * lim)
for i in xrange(lim):
    for j in xrange(lim):
        if i == j:
            distances[i, j] = 0
        else:
            if distances[i, j] == -1:
                dist = dtw_distance(clean(indices[i]), clean(indices[j]))
                distances[i, j] = dist
                distances[j, i] = dist
        bar.update()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-777dd5961c3f> in <module>()
#       9         else:
#      10             if distances[i, j] == -1:
# ---> 11                 dist = dtw_distance(clean(indices[i]), clean(indices[j]))
#      12                 distances[i, j] = dist
#      13                 distances[j, i] = dist
#
# <ipython-input-9-be53d1f71e23> in clean(idx)
#      24     y = y[:-0.05*y.shape[0], :] # Filtering common ending
#      25     x = xrange(y.shape[0])
# ---> 26     y = cos_sim(y, km.cluster_centers_)
#      27
#      28     # Filter
#
# NameError: global name 'km' is not defined

# %%
plot_idx = 22 # index of book to get signal plots

f, axarr = plt.subplots(4, sharex=True, figsize=(15, 13))

cleaned = clean(plot_idx)

for idx, ax in enumerate(axarr):
    ax.plot(cos_sim(items[plot_idx]["data"], km.cluster_centers_)[:, idx], alpha=0.3)
    ax.plot(cleaned[:, idx])
    ax.set_yticks([])
    ax.set_xlim([0, 2800])

plt.show()

# %% [markdown]
# ### Multidimensional Scaling Plot

# %%
mds = manifold.MDS(
    n_components=2,
    max_iter=3000,
    eps=1e-9,
    random_state=1234,
    dissimilarity="precomputed",
    n_jobs=1
)

pos = mds.fit(distances).embedding_

# Rotate the data
clf = RandomizedPCA(n_components=2)

pos = clf.fit_transform(pos)

# %%
fig = plt.figure(figsize=(15, 15))

plt.scatter(pos[:, 0], pos[:, 1], s=200)

for i in xrange(len(all_books)):
    plt.annotate(items[indices[i]]["name"][:-5], (pos[i, 0] + 2, pos[i, 1]))

plt.show()
